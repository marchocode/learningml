# %% [markdown]
# # My neural network

# %%
# !python --version
# Out:
# Python 3.12.3

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential
from common import load_coffee_data
# Out:
# /Users/mrc/project/learningml/.venv/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
X,y = load_coffee_data()
print(X.shape)
print(y.shape)

print(f"first label max and min is {np.max(X[:,0])} and {np.min(X[:,0])}")
print(f"first label max and min is {np.max(X[:,1])} and {np.min(X[:,1])}")
# Out:
# (200, 2)
# (200, 1)
# first label max and min is 284.99434167453603 and 151.32372212128612
# first label max and min is 15.454206928801511 and 11.512747082472469

# %%
# 归一化
norm_l = tf.keras.layers.Normalization(axis=-1)
norm_l.adapt(X)
X_norm = norm_l(X)

print(f"X_norm first label max and min is {np.max(X_norm[:,0])} and {np.min(X_norm[:,0])}")
print(f"X_norm second label max and min is {np.max(X_norm[:,1])} and {np.min(X_norm[:,1])}")
# Out:
# X_norm first label max and min is 1.6597541570663452 and -1.6852184534072876
# X_norm second label max and min is 1.793238878250122 and -1.6996712684631348

# %%
model = Sequential([
    Dense(3, activation='sigmoid', name="L1"),
    Dense(1, activation='sigmoid', name="L2"),
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ L1 (Dense)                      │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ L2 (Dense)                      │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.01),
)

# %%
Xt = np.tile(X_norm,(1000,1))
Yt= np.tile(y,(1000,1))

model.fit(
    Xt,Yt,            
    epochs=10,
)
# Out:
# Epoch 1/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 3s 399us/step - loss: 0.1822
# Epoch 2/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 3s 407us/step - loss: 0.0851
# Epoch 3/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 2s 396us/step - loss: 0.0224
# Epoch 4/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 2s 396us/step - loss: 0.0125
# Epoch 5/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 3s 403us/step - loss: 0.0084
# Epoch 6/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 3s 405us/step - loss: 0.0057
# Epoch 7/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 2s 396us/step - loss: 0.0040
# Epoch 8/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 2s 397us/step - loss: 0.0028
# Epoch 9/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 3s 406us/step - loss: 0.0020
# Epoch 10/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 3s 412us/step - loss: 0.0014

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ L1 (Dense)                      │ (32, 3)                │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ L2 (Dense)                      │ (32, 1)                │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41 (168.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 28 (116.00 B)

# %%
X_test = np.array([
    [200,13.9],  # postive example
    [200,17]])   # negative example

X_testn = norm_l(X_test)
predictions = model.predict(X_testn)
print("predictions = \n", predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# predictions =
#  [[9.9520105e-01]
#  [8.5560821e-08]]
